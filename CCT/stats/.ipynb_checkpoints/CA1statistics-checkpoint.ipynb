# %% [markdown]
# # Statistics CA1

# %%
# it's advised to import all your libraries in one single cell
from IPython.display import clear_output
import pandas as pd
import matplotlib
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
from scipy.stats import binom

# %% [markdown]
# # Task 1 - Data Analysis:
# Your task is to find a dataset of interest to you, that contains a mix of categorical and numerical variables.
# As a guideline, the dataset should have a minimum of two categorical variables and three numerical
# variables
#
#   - Use of appropriate functions in Python. [15 Marks]
#   - Clearly commenting the code in the .ipynb file. [5 Marks]
#   - Producing clear results for the chosen dataset, using appropriate statistical measures and appropriate plots. [15 Marks]
#   - The quality of the graphics included. [5 Marks]
#   - Summarising the conclusions from the analysis appropriately. [30 Marks]

# %% [markdown]
# ## Describing the CEDEL2 dataset
#
# * CEDEL2 is a large database containing the language produced by learners of Spanish as a second/foreign language (L2). This database is called a language ‘corpus’.
#
# * Language learners in this database do a profiencicy test as well as a writting task which are stored in two columns : Profieicncy test score and proficiency. There are also many charateristics of the learner and how much the learner has been exposed to spanish.
#
# * I want to explore relationships between learners characteristics and their proficiency levels
#
# * I first use the read_csv function to read the file, the shape function to show the number of rows and columns, the columns to see column names, head() to check a few row.
#
# * there are 3041 rows and 41 columns
#     * 41 columns is too many variables to analyzing in the scope of this project
#     * I will drop not relevant variables for the analysis, targeting a few core variables.
#
# * To analysise the columns with missing values I use the function is isna to check if a value is missing and the sum function sums the missing values per column and the sort_values order from lower to higher.
# * Columns with most missing values:
#     * Original text                                                     3034
#     * Language certificates (type and level)                            2786
#     * Resources used                                                    2037
#     * Stay abroad (when)                                                1984
#     * Stay abroad (where)                                               1976
#     * Minutes taken to complete the task                                1564
#     * Additional foreign language(s)                                    1546
#     * Proficiency (self-assessment) in additional language writing      1526
#     * Proficiency (self-assessment) in additional language reading      1508
#     * Proficiency (self-assessment) in additional language listening    1505
#     * Proficiency (self-assessment) in additional language speaking     1501
#     * Major                                                              905
#     * School/University/Institution                                      444
#     * Year at university/school                                          363
#     * Stay abroad (months)                                               103

# %%
# read_csv function loads a csv file as a dataframe
dataframe = pd.read_csv("./data.csv",sep="\t")

# %%
# shape function shows the number of rows and columns of the dataframe
dataframe.shape
# Out:
# (3034, 41)

# %%
# the columns list all the columns in the dataframe
dataframe.columns
# Out:
# Index(['Subcorpus', 'Filename', 'Year data collection',
#        'Placement test score (raw)', 'Placement test score (%)', 'Proficiency',
#        'Sex', 'Age', 'School/University/Institution', 'Major',
#        'Year at university/school', 'L1', 'Father's native language',
#        'Mother's nativelanguage', 'Languages spoken at home',
#        'Age of exposure to Spanish', 'Years studying Spanish',
#        'Stay abroad in Spanish speaking country (>= 1 month)',
#        'Stay abroad (where)', 'Stay abroad (when)', 'Stay abroad (months)',
#        'Language certificates (type and level)',
#        'Proficiency (self-assessment) speaking',
#        'Proficiency (self-assessment) listening',
#        'Proficiency (self-assessment) reading',
#        'Proficiency (self-assessment) writing',
#        'Proficiency (self-assessment)', 'Additional foreign language(s)',
#        'Proficiency (self-assessment) in additional language speaking',
# ...

# %%
# the head function shows the top 5 rows in the dataframe
dataframe.head()
# Out:
#   Subcorpus               Filename Year data collection  \
# 0  Learners  JP_WR_2_19_0.5_14_TAG                 2018
# 1  Learners     JP_WR_2_20_2_14_AT                 2018
# 2  Learners  JP_WR_3_19_0.5_13_TBB                 2019
# 3  Learners     EN_WR_6_20_3_1_CJB            2006-2016
# 4  Learners      EN_WR_7_26_2_2_TB            2006-2016
#
#   Placement test score (raw)  Placement test score (%)     Proficiency  \
# 0                     2 / 43                       4.7  Lower beginner
# 1                     2 / 43                       4.7  Lower beginner
# 2                     3 / 43                       7.0  Lower beginner
# 3                     6 / 43                      14.0  Lower beginner
# 4                     7 / 43                      16.3  Lower beginner
#
#       Sex   Age School/University/Institution               Major  ...  \
# 0  Female  19.0            teikyo universidad            espanola  ...
# ...

# %%
# the isna().sum() sums the number of missing values per columns
# the sort_values sort it per number
dataframe.isna().sum().sort_values()
# Out:
# Subcorpus                                                            0
# Filename                                                             0
# Year data collection                                                 0
# Placement test score (raw)                                           0
# Placement test score (%)                                             0
# Proficiency                                                          0
# Sex                                                                  0
# L1                                                                   0
# Age of exposure to Spanish                                           0
# Mother's nativelanguage                                              0
# Proficiency (self-assessment)                                        0
# Proficiency (self-assessment) writing                                0
# Proficiency (self-assessment) reading                                0
# ...

# %% [markdown]
# ## Selecting variables for analysis
#
# * to analyse columns i simply run a for loop over the columns
#     * In pandas putting the column_name inside the brackets filter only the column so I can analyse columns individually
#     * I print the value counts to see the frequency of values for each column
#     * I use the input function from python to wait my command to continue
#     * I manually selected columns that seemed relevant
#     * I create a new variable "selected_dataframe" to copy the dataframe with only the selected columns to use in the analysis
# * Relevants selected columns:
# ### Analysing the data type of the columns I selected
#
# | **Column Name**                        | **Short Description**                                           | **Statistical Datatype**    |
# |----------------------------------------|-----------------------------------------------------------------|-----------------------------|
# | Placement test score (%)               | Percentage of right answers in placement test                 | Numeric, Discrete         |
# | Proficiency                            | Proficiency level in Spanish)   | Ordinal                     |
# | Sex                                    | Gender of the learner                                           | Nominal                     |
# | Age                                    | Age of the learner in years                                     | Numeric, Discrete           |
# | L1                                     | First language of the learner                                   | Nominal                     |
# | Years studying Spanish                 | Number of years spent learning Spanish                          | Numeric, Discrete           |
# | Task title                             | Title of the language task the learner completed                | Nominal                     |

# %%
for column_name in dataframe.columns:
    print(column_name)
    print(dataframe[column_name].dtype)
    print(dataframe[column_name].value_counts())
    # commenting the input to not block the cell
    # inp = input()
    clear_output()
# Out:
# Subcorpus
# object
# Subcorpus
# Learners    3034
# Name: count, dtype: int64
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[138], line 5
#       3 print(dataframe[column_name].dtype)
#       4 print(dataframe[column_name].value_counts())
# ----> 5 inp = input()
#       6 clear_output()
#
# File ~/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
# ...

# %%
# manually create those lists from the for loop
# to filter the dataframe
interesting_columns = [ 
    "Placement test score (%)", "Proficiency", "Sex",
    "Age", "L1", "Languages spoken at home", "Age of exposure to Spanish",
    "Years studying Spanish", "Proficiency (self-assessment)", "Additional foreign language(s)",
    "Task title", "Text"
]
selected_relevant_columns = [ 
    "Placement test score (%)", "Proficiency", 
    "Sex", "Age", "L1", "Years studying Spanish",
    "Task title",
]

# %%
for column_name in selected_relevant_columns:
    print(column_name)
    print(dataframe[column_name].dtype)
    print(dataframe[column_name].value_counts())
    # commenting the input to not block the cell
    #inp = input()
    clear_output()
# Out:
# Placement test score (%)
# float64
# Placement test score (%)
# 95.3     177
# 88.4     175
# 93.0     172
# 90.7     156
# 86.0     146
# 97.7     142
# 81.4     117
# 83.7     115
# 79.1     105
# 100.0    102
# 76.7     100
# 74.4      95
# 69.8      90
# 72.1      88
# 41.9      85
# 67.4      84
# 48.8      80
# 53.5      80
# 37.2      80
# 65.1      77
# 39.5      76
# 44.2      73
# 46.5      70
# 51.2      70
# 62.8      68
# 58.1      66
# 34.9      60
# 55.8      58
# 60.5      49
# 27.9      49
# 32.6      48
# 30.2      37
# 25.6      15
# 20.9      10
# 23.3      10
# 18.6       3
# 4.7        2
# 16.3       2
# 7.0        1
# 14.0       1
# Name: count, dtype: int64
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[137], line 5
#       3 print(dataframe[column_name].dtype)
#       4 print(dataframe[column_name].value_counts())
# ----> 5 inp = input()
# ...

# %% [markdown]
# ### Analysing the data type of the columns I found interesting
#
# | **Column Name**                        | **Short Description**                                           | **Statistical Datatype**    |
# |----------------------------------------|-----------------------------------------------------------------|-----------------------------|
# | Placement test score (%)               | Percentage of right answers in placement test                 | Numeric, Discrete         |
# | Proficiency                            | Proficiency level in Spanish)   | Ordinal                     |
# | Sex                                    | Gender of the learner                                           | Nominal                     |
# | Age                                    | Age of the learner in years                                     | Numeric, Discrete           |
# | L1                                     | First language of the learner                                   | Nominal                     |
# | Languages spoken at home               | Languages spoken in the home environment                        | Nominal                     |
# | Age of exposure to Spanish             | Age at which the learner was first exposed to Spanish          | Numeric, Discrete           |
# | Years studying Spanish                 | Number of years spent learning Spanish                          | Numeric, Discrete           |
# | Proficiency (self-assessment)          | Learner's selmf-assessment of their proficiency in Spanish       | Ordinal                     |
# | Additional foreign language(s)         | Other foreign languages spoken by the learner                   | Nominal                     |
# | Task title                             | Title of the language task the learner completed                | Nominal                     |
# | text                                   | Text produced by the learner during the task                    | Nominal (text data)         |

# %%
selected_dataframe = dataframe[selected_relevant_columns].copy()

# %% [markdown]
# ## Analysing distributions
#     * I analyzed the statistical distribution of each of the selected variables
# ### SUMMARY
# ### Key results
#
# | **Column Name**                        |                                                       ||
# |----------------------------------------|-----------------------------------------------------------------|-----------------------------|
# | Placement test score (%)               | On average people get 70% of the test correct                 |  Half of the sample(median) get a score over 74.4%     |
# | Proficiency                            | 60% of the learners are upper intermediate and above |                      |
# | Sex                                    | The majority of the learners are women (72%)                                           |                      |
# | Age                                    | The average and median age is 25 and 21                                     | 75% of the sample is younger than 26           |
# | L1                                     | 63% of the learners are native english speakers                             | followed by 7% japanese speakers                     |
# | Years studying Spanish                 | Learners studied an average of 5 years of Spanish and median of 4 years                         | 75% of the sample studied up to 6years          |
# | Task title                             | The 5 top tasks represent 75% of all the exercises done by the learners                | Nominal                     |

# %% [markdown]
# ### Placement Test Score (%)
#     * On average people get 70% of the test correct
#     * Half of the sample get a score over 74.4% ~ 32 correct answers out of 43

# %%
# the describe function calculate descriptive statitics about the column
# here it calculate the mean, standard deviation the minimum, maximum values and the interquatiles values
selected_dataframe["Placement test score (%)"].describe()
# Out:
# count    3034.000000
# mean       70.464634
# std        21.762159
# min         4.700000
# 25%        51.200000
# 50%        74.400000
# 75%        88.400000
# max       100.000000
# Name: Placement test score (%), dtype: float64

# %%
# the hist function plot the histogram of the column
# It describes how frequent a certain interval is in the sample
# we see in the y-axis the frequency/count for a certain 
# interval of test score 
selected_dataframe["Placement test score (%)"].hist()
# Out:
# <Axes: >

# %%
# the boxplot function from the seaborn library
# plots the boxplot of the column
# It describes the quantiles of the distribution 
# the same values that the describe function shows
sns.boxplot(selected_dataframe["Placement test score (%)"])
# Out:
# <Axes: ylabel='Placement test score (%)'>

# %% [markdown]
# ### Proficiency
#     * the sample have:
#         * Upper advanced 13%
#         * Lower advanced 25%
#         * Upper intermediate 22%
#         * Lower intermediate 18%
#         * Upper beginner 17%
#         * Lower beginner 3%
#     * So most of learners are more advanced than beginners
#     * 60% of the learners are upper intermediate and above

# %%
# for categorical variables I wanted to see how frequent each 
# category is so I used the value_counts function to count
# how many observations for each unique value and order the 
# Proficiency with the sort_index function
selected_dataframe["Proficiency"].value_counts().sort_index()
# Out:
# Proficiency
# Upper advanced        421
# Lower advanced        764
# Upper intermediate    679
# Lower intermediate    548
# Upper beginner        529
# Lower beginner         93
# Name: count, dtype: int64

# %%
# I then calculate the percentage by dividing 
# the absolute number by the size of the column proficiency
print("Upper advanced", 421/len(selected_dataframe["Proficiency"]))
print("Lower advanced", 764/len(selected_dataframe["Proficiency"]))
print("Upper intermediate", 679/len(selected_dataframe["Proficiency"]))
print("Lower intermediate", 548/len(selected_dataframe["Proficiency"]))
print("Upper beginner", 529/len(selected_dataframe["Proficiency"]))
print("Lower beginner", 93/len(selected_dataframe["Proficiency"]))
# Out:
# Upper advanced 0.13876071193144363
# Lower advanced 0.25181278839815424
# Upper intermediate 0.2237969676994067
# Lower intermediate 0.1806196440342782
# Upper beginner 0.17435728411338167
# Lower beginner 0.030652603823335532

# %%
# I use pandas categorical to order the categories since Proficiency is a Ordinal variables
# so that the histogram is in the right order
# The histogram shows from lower proficiency to higher proficiency in order
selected_dataframe["Proficiency"] = pd.Categorical(values=selected_dataframe["Proficiency"], categories=["Upper advanced", "Lower advanced", "Upper intermediate", "Lower intermediate", "Upper beginner", "Lower beginner"]
)
selected_dataframe["Proficiency"].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### Sex
#
# * there are in the sample
#     * 72.8% women
#     * 27.1% men

# %%
# Since sex is a nominal variable I want
# to verify the frequency of each category
selected_dataframe["Sex"].value_counts()
# Out:
# Sex
# Female    2210
# Male       824
# Name: count, dtype: int64

# %%
# The hist function
# plots the histogram for the sex column
selected_dataframe["Sex"].hist()
# Out:
# <Axes: >

# %%
# Here I calculate the percentage of female and male
# over the size of the Sex column
total=len(selected_dataframe["Sex"])
print("Female", 2210/total)
print("Male", 824/total)
# Out:
# Female 0.7284113381674358
# Male 0.27158866183256425

# %% [markdown]
# ### Age
#     * On average people are approximately 25 years old
#     * Half of the sample is younger than 21
#     * 75% of the sample is younger than 26
#     * the great majority is under 30

# %%
# As Age is a numeric variable we want to
# describe its distribution
# Again the describe function describes
# the count, mean, standard deviation, the min and max value and the quantiles of the Age column
selected_dataframe["Age"].describe()
# Out:
# count    3030.000000
# mean       24.954125
# std        11.127056
# min        13.000000
# 25%        19.000000
# 50%        21.000000
# 75%        26.000000
# max        88.000000
# Name: Age, dtype: float64

# %%
# Here the hist function
# plots the histogram for the age column
selected_dataframe["Age"].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### First Language (L1)
#
# * Most of the learners in the sample speak english:
#     * English 63%
#     * Japanese 7%
#     * Greek 7%
#     * Portuguese 5%
#     * Russian 3%
#     * Italian 2%
#     * German 2%
#     * Arabic 2%
#     * Dutch 1%
#     * French 1%
#     * Chinese 0.7%

# %%
# Since First Language is a nominal variable I wanted to understand 
# what are the most frequent Categories (languages).
selected_dataframe["L1"].value_counts()
# Out:
# L1
# English       1931
# Japanese       243
# Greek          216
# Portuguese     164
# Russian        101
# Italian         83
# German          82
# Arabic          74
# Dutch           60
# French          58
# Chinese         22
# Name: count, dtype: int64

# %%
# The hist function
# plots the histogram for the L1 column
selected_dataframe["L1"].hist()
# Out:
# <Axes: >

# %%
# Calculating the percentage of each Language
# over the size of the L1 column
total=3041 
print("English", 1931/total)
print("Japanese", 243/total)
print("Greek", 216/total)
print("Portuguese", 164/total)
print("Russian", 101/total)
print("Italian", 83/total)
print("German", 82/total)
print("Arabic", 74/total)
print("Dutch", 60/total)
print("French", 58/total)
print("Chinese", 22/total)
# Out:
# English 0.6349884906280828
# Japanese 0.07990792502466294
# Greek 0.07102926668858928
# Portuguese 0.053929628411706676
# Russian 0.03321275896086814
# Italian 0.027293653403485694
# German 0.026964814205853338
# Arabic 0.024334100624794474
# Dutch 0.019730351857941468
# French 0.01907267346267675
# Chinese 0.007234462347911871

# %% [markdown]
# ### Years studying Spanish
#     * On average people sutdy approximately 5 years of spanish
#     * Half of the sample studied up to 4 years of spanish.
#     * 75% of the sample studied up to 6 years.

# %%
#Years studying Spanish is a numeric variable I analyse similar to the Age column
# Again the describe function describes
# the count, mean, standard deviation, the min and max value and the quantiles of the Age column
selected_dataframe["Age"].describe()
selected_dataframe["Years studying Spanish"].describe()
# Out:
# count    2999.00000
# mean        4.96012
# std         4.71978
# min         0.00000
# 25%         2.00000
# 50%         4.00000
# 75%         6.00000
# max        65.00000
# Name: Years studying Spanish, dtype: float64

# %%
selected_dataframe["Years studying Spanish"].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### Task title

# %%
# print the size of the unique titles
print(len(selected_dataframe["Task title"].unique()))
# Out:
# 14

# %%
selected_dataframe["Task title"].value_counts()
# Out:
# Task title
# 14. Chaplin                   1040
# 1. Region where you live       457
# 4. Last year holidays          306
# 2. Famous person               262
# 5. Future plans                237
# 6. Recent trip                 206
# 13. Frog                       150
# 3. Film                        133
# 10. Gay couples                 81
# 7. An experience                56
# 9. Anti-smoking law             36
# 12. Immigration                 32
# 11. Marijuana legalization      19
# 8. Terrorism                    19
# Name: count, dtype: int64

# %%
# size of the Task  title column
total=len(selected_dataframe["Task title"])
print("Chaplin", 1040/total)
print("Region where you live", 457/total)
print("Last year holidays", 306/total)
print("Famous Person", 262/total)
print("Recent Trip", 237/total)
print("Sum of the percentage", 0.34278180619644033+0.15062623599208966+0.1008569545154911+0.08635464733025709+0.07811470006591958)
# Out:
# Chaplin 0.34278180619644033
# Region where you live 0.15062623599208966
# Last year holidays 0.1008569545154911
# Famous Person 0.08635464733025709
# Recent Trip 0.07811470006591958
# Sum of the percentage 0.7587343441001978

# %% [markdown]
# ## Analysing relationships
#
#
# ### SUMMARY
# * Females have higher median in the Placement test score (%)
# * More proficient learners are usually older
# * Italians natives have the highest mean in the test score
# * followed by chinese and german natives

# %% [markdown]
# ### test score according to sex

# %%
# The box plot function plots the distribution
# of Placement Test Score according to Female and Male
# Specially we can see the difference in the median and
# other quantiles of the two groups
sns.boxplot(x="Placement test score (%)", y="Sex",
            data=selected_dataframe)
# Out:
# <Axes: xlabel='Placement test score (%)', ylabel='Sex'>

# %% [markdown]
# ### profiency according to sex
#
#     * Both sexes seem to have similar distribution of proficiency even though Female have higher median test score

# %%
sns.histplot(data=selected_dataframe, stat="percent", multiple="stack",
             x="Proficiency", kde=False,
             palette="pastel", hue="Sex",
             element="bars", legend=True)
# Out:
# <Axes: xlabel='Proficiency', ylabel='Percent'>

# %% [markdown]
# ### test score according to Age
#     * I couldn't find any specific pattern relating age to test score

# %%
# The scatterplot relate two numeric variables
# it shows test score in the x-axis and age in the y-axis
sns.scatterplot(x="Placement test score (%)", y="Age",
            data=selected_dataframe)
# Out:
# <Axes: xlabel='Placement test score (%)', ylabel='Age'>

# %% [markdown]
# ### profiency according to age
#     * More advanced learner are usually older

# %%
# This boxplot show the distribution of age
# according to different proficiency groups
# The boxplot function splits the proficiency column
# in each group of the column
sns.boxplot(x="Age", y="Proficiency",
            data=selected_dataframe)
# Out:
# <Axes: xlabel='Age', ylabel='Proficiency'>

# %% [markdown]
# ### test score according to first language
#     * Italians have the highest mean in the test score
#     * followed by chinese and german

# %%
# Similar to the Proficiency boxplot this show the distribution of Score
# according two different proficiency groups
# The boxplot function splits the proficiency column
# in each group of the column
sns.boxplot(x="Placement test score (%)", y="L1",
            data=selected_dataframe)
# Out:
# <Axes: xlabel='Placement test score (%)', ylabel='L1'>

# %% [markdown]
# ### Percentage of nationalities per proficiency

# %%
# the histplot plots a stacked chart of
# the first languages across profiency groups.
# It only shows that English is the majority spoken language across
# all proficiency groups
sns.histplot(data=selected_dataframe, stat="percent", multiple="stack",
             x="Proficiency", kde=False,
             palette="pastel", hue="L1",
             element="bars", legend=True)
# Out:
# <Axes: xlabel='Proficiency', ylabel='Percent'>

# %% [markdown]
# ### Test score according to years studying spanish

# %%
sns.scatterplot(y="Placement test score (%)", x="Years studying Spanish",
            data=selected_dataframe)
# Out:
# <Axes: xlabel='Years studying Spanish', ylabel='Placement test score (%)'>

# %% [markdown]
# # Task 2 - Discrete Probability

# %% [markdown]
# ## Task 2 Execise 1 What is the probability of rolling exactly two 6s in five rolls of a fair die?
# Assuming every roll of the die is one try and independent of each other, we have 5 independent tries of the same die. This scenario is similar to a Binomial distribution that represents the number of successes in a fixed number of successes or fails. In this exercise one success is if one dice is equal to 6.
#
# So assuming the binomial distribution and following the binomial distribution formula :
# We need to tell the value of n,k and p to calculate the probability.
# We have 5 tries so n=5, k is the number of successes so k=2, and p is the probability of success in each trial ( if the die has 6 sides p=⅙).

# %%
# using the binom function from the scipy library (https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.binom.html)
# Using the binom function to calculate the probability with n, p and k
binomial_distribution = binom(n=5, p=1/6)
binomial_distribution.pmf(k=2)
# Out:
# np.float64(0.16075102880658423)

# %% [markdown]
# ## Task 2 Execise 2 The number of industrial injuries on average per working week in a factory is 0.75. Assuming that the distribution of injuries follows a Poisson distribution, find the probability that in a particular week there will be no more than two accidents.
#
#
# The poisson distribution is a discrete distribution so its value can only be 0,1,2 and so on.
# The formula of the poisson distribution just requires a lambda parameter which represents the average rate of occurrence over a given interval. In thi11s exercise lambda is 0.75.
# So the event “no more than two accidents” means either 0 or 1 accidents in a week.
# Using the poisson formula we can calculate P(X=0) + P(X=1).

# %% [markdown]
# # Task 3
# The time a person spends at Dublin Zoo is Normally distributed with a mean of 90 minutes and a standard deviation of 10 minutes. Using this distribution, answer the following:
#  If a visitor is selected at random, find the probability that they will spend at most 85 minutes visiting the zoo.
#
#  If a visitor is selected at random, find the probability that they will spend at least 100 minutes visiting the zoo.
#  Given that you know that a particular visitor has spent longer than average visiting the Zoo, what is the probability that they have spent more than 100 minutes there?
